# %%
import os
os.chdir('E:/Interview ROunds/Hans Creations/2nd round')

# %%
import pandas as pd
df = pd.read_csv('BigBasket.csv')
df.head()
# Out:
#      ProductName   Brand   Price  DiscountPrice  \
# 0  Onion (Loose)  Fresho   69.75           52.0
# 1          Onion  Fresho  174.35          130.0
# 2  Onion (Loose)  Fresho   34.87           26.0
# 3          Onion  Fresho   69.74           52.0
# 4  Onion (Loose)  Fresho  174.37          129.0
#
#                                            Image_Url Quantity  \
# 0  https://www.bigbasket.com/media/uploads/p/l/40...     2 kg
# 1  https://www.bigbasket.com/media/uploads/p/l/12...     5 kg
# 2  https://www.bigbasket.com/media/uploads/p/l/10...     1 kg
# 3  https://www.bigbasket.com/media/uploads/p/l/12...     2 kg
# 4  https://www.bigbasket.com/media/uploads/p/l/10...     5 kg
#
#               Category             SubCategory  \
# 0  Fruits & Vegetables  Potato, Onion & Tomato
# 1  Fruits & Vegetables  Potato, Onion & Tomato
# 2  Fruits & Vegetables  Potato, Onion & Tomato
# 3  Fruits & Vegetables  Potato, Onion & Tomato
# 4  Fruits & Vegetables  Potato, Onion & Tomato
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8208 entries, 0 to 8207
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProductName    8208 non-null   object
#  1   Brand          8208 non-null   object
#  2   Price          8208 non-null   float64
#  3   DiscountPrice  8208 non-null   float64
#  4   Image_Url      8208 non-null   object
#  5   Quantity       8208 non-null   object
#  6   Category       8208 non-null   object
#  7   SubCategory    8208 non-null   object
#  8   Absolute_Url   8208 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 577.2+ KB

# %% [markdown]
# Perform basic data quality checks

# %%
df.isna().sum()
# Out:
# ProductName      0
# Brand            0
# Price            0
# DiscountPrice    0
# Image_Url        0
# Quantity         0
# Category         0
# SubCategory      0
# Absolute_Url     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no missing values and no duplicated rows in this dataset

# %% [markdown]
# ## Number of orders placed for Dettol

# %%
df[df['Brand']=='Dettol']
# Out:
#                                             ProductName   Brand    Price  \
# 46         Bathing Bar Soap - Germ Protection, Original  Dettol   600.00
# 47                          Bathing Bar Soap - Original  Dettol   240.00
# 48    Original Bathing Bar Soap, Daily Protection fr...  Dettol    75.00
# 49                              Bathing Soap - Original  Dettol   300.00
# 50                              Bathing Soap - Original  Dettol   150.00
# 51         Bathing Bar Soap - Germ Protection, Original  Dettol   450.00
# 94                       Antiseptic Disinfectant Liquid  Dettol    66.55
# 95                       Antiseptic Disinfectant Liquid  Dettol   127.77
# 96                       Antiseptic Disinfectant Liquid  Dettol   214.06
# 97                       Antiseptic Disinfectant Liquid  Dettol  1641.59
# 98                       Antiseptic Disinfectant Liquid  Dettol   331.41
# 99                       Antiseptic Disinfectant Liquid  Dettol    33.27
# ...

# %%
len(df[df['Brand']=='Dettol'])
# Out:
# 32

# %%
unique_brands = df['Brand'].sort_values(ascending=False).unique()
unique_brands
# Out:
# array(['tagz', 'suny', 'sumeru', 's.Oliver', "nature's eco",
#        'kwality walls', 'iD Fresho', 'dhanalakshmi', 'cocotuft',
#        'bb Combo', 'Zodak', 'Ziofit', 'Zerobeli', 'ZUII ORGANIC',
#        'ZM Zayn & Myza', 'ZLADE', 'Yummiez', 'Yujing', 'Yongsheng',
#        'Yoga Bar', 'Yera', 'Yardley London', 'YORK', 'Xishifeng',
#        'Wow Skin Science', 'Wow Momo', 'Wipro Garnet ', 'Wipro',
#        'Winkies', 'Wingreens Farms', 'Wild Stone', 'Wild Ideas',
#        'Wiggles.in', 'WickedGud', 'Whisper ', 'Wet N Wild', 'Wellberg',
#        'Wellbeing Nutrition', 'Weiman', 'Vitress', 'Vinayak', 'VictorPro',
#        'Veriza', 'Vega', 'Veeba', 'Vedapure', 'Vedaearth', 'Vcare ',
#        'Vaseline', 'Valley Spice', 'Vaadi', 'VLCC', 'VILLAIN', 'VHealth',
#        'VAHDAM', 'Ustraa', 'Urban gabru', 'Upakarma', 'Unroll',
#        'Unique Arts & Interiors', 'Unica', 'Unibic', 'URBANTRAY',
#        'UNIBIC FOODS', 'Turn Organic ', 'Tummy Pops', 'Trueware',
# ...

# %% [markdown]
# ## Sales from Dettol Products

# %%
fil1 = df['Brand'] == 'Dettol'
df[fil1].head(2)
# Out:
#                                      ProductName   Brand  Price  \
# 46  Bathing Bar Soap - Germ Protection, Original  Dettol  600.0
# 47                   Bathing Bar Soap - Original  Dettol  240.0
#
#     DiscountPrice                                          Image_Url Quantity  \
# 46          456.0  https://www.bigbasket.com/media/uploads/p/l/12...  8x125 g
# 47          225.6  https://www.bigbasket.com/media/uploads/p/l/12...   6x75 g
#
#             Category           SubCategory  \
# 46  Beauty & Hygiene  Bathing Bars & Soaps
# 47  Beauty & Hygiene  Bathing Bars & Soaps
#
#                                          Absolute_Url
# 46  https://www.bigbasket.com/pd/1206304/dettol-ba...
# 47  https://www.bigbasket.com/pd/1208387/dettol-ba...

# %%
Sales = sum(df[fil1]['DiscountPrice'])
Sales
# Out:
# 7702.469999999999

# %% [markdown]
# ### Sales from Dettol brand are 7702.469

# %%
df['Absolute_Url']
# Out:
# 0       https://www.bigbasket.com/pd/40075537/fresho-o...
# 1       https://www.bigbasket.com/pd/1201414/fresho-on...
# 2       https://www.bigbasket.com/pd/10000148/fresho-o...
# 3       https://www.bigbasket.com/pd/1201413/fresho-on...
# 4       https://www.bigbasket.com/pd/10000150/fresho-o...
#                               ...
# 8203    https://www.bigbasket.com/pd/40237020/bvishal-...
# 8204    https://www.bigbasket.com/pd/40237682/bvishal-...
# 8205    https://www.bigbasket.com/pd/40175488/pac-foun...
# 8206    https://www.bigbasket.com/pd/40200885/the-heal...
# 8207    https://www.bigbasket.com/pd/40224773/lakme-bl...
# Name: Absolute_Url, Length: 8208, dtype: object

# %%
df['Image_Url']
# Out:
# 0       https://www.bigbasket.com/media/uploads/p/l/40...
# 1       https://www.bigbasket.com/media/uploads/p/l/12...
# 2       https://www.bigbasket.com/media/uploads/p/l/10...
# 3       https://www.bigbasket.com/media/uploads/p/l/12...
# 4       https://www.bigbasket.com/media/uploads/p/l/10...
#                               ...
# 8203    https://www.bigbasket.com/media/uploads/p/l/40...
# 8204    https://www.bigbasket.com/media/uploads/p/l/40...
# 8205    https://www.bigbasket.com/media/uploads/p/l/40...
# 8206    https://www.bigbasket.com/media/uploads/p/l/40...
# 8207    https://www.bigbasket.com/media/uploads/p/l/40...
# Name: Image_Url, Length: 8208, dtype: object

# %% [markdown]
# ## Demographic data is not provided in this dataset.

# %% [markdown]
# ### How many orders were placed for each category

# %%
df[fil1]['Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Maximum orders were placed for Beauty & Hygiene category

# %% [markdown]
# ### How many orders were placed by each subcategory

# %%
import matplotlib.pyplot as plt

# %%
df[fil1]['SubCategory'].value_counts().plot(kind='bar')
plt.xticks(rotation=65)
plt.show()

# %% [markdown]
# ### Bathing Bars & Soaps are the highest sub category orders followed by Antiseptics & Bandages

# %% [markdown]
# ### What is the most preferred Quantity based on orders

# %%
df[fil1]['Quantity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Quantity'>

# %%
dettol_df = df[fil1].copy()
dettol_df.head(2)
# Out:
#                                      ProductName   Brand  Price  \
# 46  Bathing Bar Soap - Germ Protection, Original  Dettol  600.0
# 47                   Bathing Bar Soap - Original  Dettol  240.0
#
#     DiscountPrice                                          Image_Url Quantity  \
# 46          456.0  https://www.bigbasket.com/media/uploads/p/l/12...  8x125 g
# 47          225.6  https://www.bigbasket.com/media/uploads/p/l/12...   6x75 g
#
#             Category           SubCategory  \
# 46  Beauty & Hygiene  Bathing Bars & Soaps
# 47  Beauty & Hygiene  Bathing Bars & Soaps
#
#                                          Absolute_Url
# 46  https://www.bigbasket.com/pd/1206304/dettol-ba...
# 47  https://www.bigbasket.com/pd/1208387/dettol-ba...

# %% [markdown]
# ### Remove statistically insignificant columns

# %%
dettol_df.drop(columns=['Image_Url','Absolute_Url','Price'],inplace=True)
dettol_df.head(2)
# Out:
#                                      ProductName   Brand  DiscountPrice  \
# 46  Bathing Bar Soap - Germ Protection, Original  Dettol          456.0
# 47                   Bathing Bar Soap - Original  Dettol          225.6
#
#    Quantity          Category           SubCategory
# 46  8x125 g  Beauty & Hygiene  Bathing Bars & Soaps
# 47   6x75 g  Beauty & Hygiene  Bathing Bars & Soaps
